# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('kugupu_merged.csv')

# %%
sns.histplot(df['Jeff'], bins=1000, kde=False)
# Out:
# <Axes: xlabel='Jeff', ylabel='Count'>

# %%
(df['Jeff'] > 0.0).sum()
# Out:
# 5807
